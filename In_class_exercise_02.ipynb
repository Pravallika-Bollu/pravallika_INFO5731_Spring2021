# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallika-Bollu/pravallika_INFO5731_Spring2021/blob/main/In_class_exercise_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The second In-class-exercise (1/27/2021, 20 points in total)**

# %% [markdown]
# (1) Write a Python program to find the duplicate elements in a given array of integers. Return -1 If there are no such elements. (4 points)

# %%
# write your answer here
a=[8,9,5,4,2,5,6,6,8];
count=0

print("Duplicate elements are")
for i in range(0,len(a)):
  for j in range(i+1,len(a)):
    if (a[i]==a[j]):
      print(a[j])
      count=count+1
if (count==0):
    print("-1")
# Out:
# Duplicate elements are
# 8
# 5
# 6

# %% [markdown]
# (2) Write a Python program to select all the Sundays of a specified year. (4 points)

# %%
# write your answer here
from datetime import date,timedelta

def all_sundays(year):
  dt=date(year,1,1)
  dt+=timedelta(days=6-dt.weekday())
  while dt.year==year:
    yield dt
    dt+=timedelta(days=7)
  
for s in all_sundays(2021):
  print(s)
# Out:
# 2021-01-03
# 2021-01-10
# 2021-01-17
# 2021-01-24
# 2021-01-31
# 2021-02-07
# 2021-02-14
# 2021-02-21
# 2021-02-28
# 2021-03-07
# 2021-03-14
# 2021-03-21
# 2021-03-28
# 2021-04-04
# 2021-04-11
# 2021-04-18
# 2021-04-25
# 2021-05-02
# 2021-05-09
# 2021-05-16
# 2021-05-23
# 2021-05-30
# 2021-06-06
# 2021-06-13
# 2021-06-20
# 2021-06-27
# 2021-07-04
# 2021-07-11
# 2021-07-18
# 2021-07-25
# 2021-08-01
# 2021-08-08
# 2021-08-15
# 2021-08-22
# 2021-08-29
# 2021-09-05
# 2021-09-12
# 2021-09-19
# 2021-09-26
# 2021-10-03
# 2021-10-10
# 2021-10-17
# 2021-10-24
# 2021-10-31
# 2021-11-07
# 2021-11-14
# 2021-11-21
# 2021-11-28
# 2021-12-05
# 2021-12-12
# 2021-12-19
# 2021-12-26

# %% [markdown]
# (3) Python files reading and writing. Download the “[exercise_02_data _collection.zip](https://github.com/unt-iialab/info5731_spring2021/blob/main/class_exercises/exercise_02_data_collection.zip)” to your local and un-zip it.
#
# *   Write a program to read all the txt files and save the sentences in all the files into one csv file with two columns, the first column is sentence id (txt file name+sentence line number), the second column is the sentence text content. (4 points)
# *   Remove all the punctuations from the sentences, save the processed sentences into a new column in the same csv file. (4 points)
# *   Ask the user to enter a word, return all the sentences that include this word, three kinds of information should be returned: sentence id, sentence text content, the count that user input word appear in the sentence. (4 points)

# %%
# write your answer here
import os
import string
from glob import glob
from pathlib import Path
import csv
count = int(0)
punc = string.punctuation
p=Path('InClassExercise2')
txtFiles=p.glob('*.txt')
print(txtFiles)
output=open('result.csv','w')
output_write=csv.writer(output)
for txtFile in txtFiles:  
  with open(txtFile,'r') as text:
    data = text.readlines()
    for i,sentence in enumerate(data):
      count = count + 1
      sentence2 = sentence
      for word in sentence2:
        if word in punc:
          sentence2 = sentence2.replace(word,"")
      print(txtFile.name+ ' ' +str(count),sentence,sentence2)
      output_write.writerow([txtFile.name+ ' ' +str(count),sentence,sentence2])
# Out:
# <generator object Path.glob at 0x7ff656c21f10>
# ARTHROTEC.36.txt 1 Took my 1st pill 5 hours ago & almost immediately experienced sever abdominal cramps.
#  Took my 1st pill 5 hours ago  almost immediately experienced sever abdominal cramps
#
# ARTHROTEC.36.txt 2 Much like period cramps.
#  Much like period cramps
#
# ARTHROTEC.36.txt 3 Just took 2 Advil to try & combat the cramping pain!
#  Just took 2 Advil to try  combat the cramping pain
#
# ARTHROTEC.36.txt 4 Also; some diarrhea.
#  Also some diarrhea
#
# ARTHROTEC.36.txt 5 Will not take any more of these!.
#  Will not take any more of these
#
# ARTHROTEC.44.txt 6 This medicine helped with the heel spurs, however the side effects were far worse and not worth taking the medicine.
#  This medicine helped with the heel spurs however the side effects were far worse and not worth taking the medicine
#
# ARTHROTEC.44.txt 7 I had bad gas and SEVERE diarrhea along with stomach cramps and nausea.
# ...

# %% [markdown]
# (4) Install packages nltk, numpy, scipy, pandas, and sklearn on Google Colab. Write a program to test whether they are installed successfully. (3 points for extra)

# %%
# write your answer here
# !pip install nltk
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install sklearn

import nltk
import numpy
import scipy
import pandas
import sklearn
